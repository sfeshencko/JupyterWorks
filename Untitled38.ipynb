# %%
a=np.random.randint(3, 7, 64)
a*1.73
# Out:
# array([ 6.92,  6.92,  8.65,  5.19, 10.38,  8.65, 10.38,  6.92,  6.92,
#         8.65, 10.38,  8.65,  5.19,  5.19,  5.19,  8.65,  5.19, 10.38,
#         8.65,  8.65,  8.65, 10.38,  5.19,  5.19,  6.92,  5.19, 10.38,
#         8.65,  5.19,  6.92, 10.38, 10.38,  8.65, 10.38,  8.65,  8.65,
#         5.19,  5.19, 10.38, 10.38, 10.38,  8.65,  6.92,  6.92, 10.38,
#         8.65, 10.38,  8.65, 10.38, 10.38,  5.19,  8.65, 10.38,  6.92,
#        10.38,  6.92,  6.92,  6.92,  6.92,  6.92, 10.38,  8.65,  8.65,
#         8.65])

# %%
y = [ 5.1,  8.5,  8.5,  6.8,  6.8,  8.5,  1.7,  3.4,  1.7,  1.7,  8.5,
        5.1,  5.1,  5.1, 10.2,  6.8,  8.5,  1.7,  6.8,  8.5,  6.8,  8.5,
       10.2, 10.2,  8.5,  8.5,  6.8,  3.4, 10.2,  3.4,  3.4,  8.5,  1.7,
        3.4,  8.5,  8.5, 10.2,  8.5,  6.8,  5.1,  3.4,  3.4,  8.5,  6.8,
        8.5,  6.8,  3.4,  1.7,  6.8,  1.7,  8.5,  1.7,  5.1,  1.7,  3.4,
        5.1,  6.8,  8.5,  6.8,  6.8, 10.2,  6.8,  1.7,  3.4]
y1 = np.sort(y)
x = [i for i in range(64)]
my = [0,10,20,27,41,58]
F = [0,10/64,20/64,27/64,41/64,58/64]
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.plot(x,y)
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(x,y1)
plt.grid(True)
#plt.subplot(2,2,3)
#plt.plot(my,F)
#plt.grid(True)
array_d = {}.fromkeys(y, 0)
for a in y:
    array_d[a] += 1
print(array_d)
# Out:
# {8.5: 17, 3.4: 10, 1.7: 10, 6.8: 14, 10.2: 6, 5.1: 7}

# %%
y = [ 7.6,  3.8,  7.6,  7.6,  1.9,  9.5, 11.4,  9.5,  5.7,  5.7,  1.9,
        9.5, 11.4,  3.8,  5.7,  9.5,  5.7,  7.6,  7.6,  9.5,  5.7,  7.6,
        7.6,  3.8,  3.8, 11.4,  9.5,  3.8,  9.5,  9.5,  9.5,  5.7,  3.8,
        1.9,  7.6,  1.9,  3.8,  5.7,  9.5,  9.5, 11.4,  1.9,  5.7,  9.5,
        3.8,  3.8,  7.6,  9.5,  9.5,  7.6, 11.4,  1.9,  7.6,  1.9,  9.5,
        9.5,  3.8, 11.4,  7.6,  5.7,  9.5,  9.5,  3.8,  3.8]
y1 = np.sort(y)
x = [i for i in range(64)]
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.plot(x,y,c='r')
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(x,y1,c='r')
plt.grid(True)
array_d = {}.fromkeys(y, 0)
for a in y:
    array_d[a] += 1
print(array_d)
# Out:
# {9.5: 18, 11.4: 6, 5.7: 9, 7.6: 12, 1.9: 7, 3.8: 12}

# %%
y = [10.38,  5.19,  8.65,  6.92,  6.92,  5.19,  6.92, 10.38,  8.65,
        5.19,  6.92, 10.38,  6.92,  8.65,  5.19, 10.38,  6.92,  6.92,
        8.65,  8.65,  8.65, 10.38,  8.65,  5.19,  5.19, 10.38, 10.38,
        5.19,  8.65, 10.38,  5.19, 10.38,  5.19,  6.92,  5.19, 10.38,
        6.92,  8.65,  6.92,  6.92,  5.19,  8.65,  8.65,  6.92,  5.19,
        5.19, 10.38, 10.38,  8.65, 10.38,  6.92, 10.38,  8.65, 10.38,
       10.38,  6.92,  8.65,  6.92,  5.19,  6.92, 10.38,  8.65,  6.92,
        6.92]
y1 = np.sort(y)
x = [i for i in range(64)]
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.plot(x,y,c='y')
plt.grid(True)
plt.subplot(2,2,2)
plt.plot(x,y1,c='y')
plt.grid(True)
array_d = {}.fromkeys(y, 0)
for a in y:
    array_d[a] += 1
print(array_d)
# Out:
# {10.38: 17, 5.19: 14, 8.65: 15, 6.92: 18}

# %%
y = [10.38,  5.19,  8.65,  6.92,  6.92,  5.19,  6.92, 10.38,  8.65,
        5.19,  6.92, 10.38,  6.92,  8.65,  5.19, 10.38,  6.92,  6.92,
        8.65,  8.65,  8.65, 10.38,  8.65,  5.19,  5.19, 10.38, 10.38,
        5.19,  8.65, 10.38,  5.19, 10.38,  5.19,  6.92,  5.19, 10.38,
        6.92,  8.65,  6.92,  6.92,  5.19,  8.65,  8.65,  6.92,  5.19,
        5.19, 10.38, 10.38,  8.65, 10.38,  6.92, 10.38,  8.65, 10.38,
       10.38,  6.92,  8.65,  6.92,  5.19,  6.92, 10.38,  8.65,  6.92,
        6.92]
y1 = np.sort(y)
y1
# Out:
# array([ 5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,
#         5.19,  5.19,  5.19,  5.19,  5.19,  6.92,  6.92,  6.92,  6.92,
#         6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,
#         6.92,  6.92,  6.92,  6.92,  6.92,  8.65,  8.65,  8.65,  8.65,
#         8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,
#         8.65,  8.65, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38,
#        10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38,
#        10.38])

# %%
y_sort = [ 5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,  5.19,
        5.19,  5.19,  5.19,  5.19,  5.19,  6.92,  6.92,  6.92,  6.92,
        6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,  6.92,
        6.92,  6.92,  6.92,  6.92,  6.92,  8.65,  8.65,  8.65,  8.65,
        8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,  8.65,
        8.65,  8.65, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38,
       10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38, 10.38,
       10.38]
